# %% [markdown]
# # Fully-Connected Neural Nets
# In the previous homework you implemented a fully-connected two-layer neural network on CIFAR-10. The implementation was simple but not very modular since the loss and gradient were computed in a single monolithic function. This is manageable for a simple two-layer network, but would become impractical as we move to bigger models. Ideally we want to build networks using a more modular design so that we can implement different layer types in isolation and then snap them together into models with different architectures.
#
# In this exercise we will implement fully-connected networks using a more modular approach. For each layer we will implement a `forward` and a `backward` function. The `forward` function will receive inputs, weights, and other parameters and will return both an output and a `cache` object storing data needed for the backward pass, like this:
#
# ```python
# def layer_forward(x, w):
#   """ Receive inputs x and weights w """
#   # Do some computations ...
#   z = # ... some intermediate value
#   # Do some more computations ...
#   out = # the output
#
#   cache = (x, w, z, out) # Values we need to compute gradients
#
#   return out, cache
# ```
#
# The backward pass will receive upstream derivatives and the `cache` object, and will return gradients with respect to the inputs and weights, like this:
#
# ```python
# def layer_backward(dout, cache):
#   """
#   Receive derivative of loss with respect to outputs and cache,
#   and compute derivative with respect to inputs.
#   """
#   # Unpack cache values
#   x, w, z, out = cache
#
#   # Use values in cache to compute derivatives
#   dx = # Derivative of loss with respect to x
#   dw = # Derivative of loss with respect to w
#
#   return dx, dw
# ```
#
# After implementing a bunch of layers this way, we will be able to easily combine them to build classifiers with different architectures.
#
# In addition to implementing fully-connected networks of arbitrary depth, we will also explore different update rules for optimization, and introduce Dropout as a regularizer and Batch Normalization as a tool to more efficiently optimize deep networks.

# %%
# As usual, a bit of setup

import time
import numpy as np
import matplotlib.pyplot as plt
from cs231n.classifiers.fc_net import *
from cs231n.data_utils import get_CIFAR10_data
from cs231n.gradient_check import eval_numerical_gradient, eval_numerical_gradient_array
from cs231n.solver import Solver

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
  """ returns relative error """
  return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %%
# Load the (preprocessed) CIFAR10 data.

data = get_CIFAR10_data()
for k, v in data.iteritems():
  print '%s: ' % k, v.shape
# Out:
# X_val:  (1000L, 3L, 32L, 32L)
# X_train:  (49000L, 3L, 32L, 32L)
# X_test:  (1000L, 3L, 32L, 32L)
# y_val:  (1000L,)
# y_train:  (49000L,)
# y_test:  (1000L,)

# %%
# im=np.empty((32,32,3))
# for i in range(3):
#     im[:,:,i]=data['X_val'][10,i,:,:]
im=data['X_val'].transpose(0,2,3,1)
print(im.shape)
plt.figure(figsize=[1,1])
image=((im[int(np.random.uniform(low=0,high=im.shape[0])),:,:,:]+150)/300)#.astype('uint8')
plt.imshow(image)#,interpolation='nearest')
plt.axis('off')
# Out:
# (1000L, 32L, 32L, 3L)
# (-0.5, 31.5, 31.5, -0.5)

# %% [markdown]
# # Affine layer: foward
# Open the file `cs231n/layers.py` and implement the `affine_forward` function.
#
# Once you are done you can test your implementaion by running the following:

# %%
# Test the affine_forward function

num_inputs = 2
input_shape = (4, 5, 6)
output_dim = 3

input_size = num_inputs * np.prod(input_shape)
weight_size = output_dim * np.prod(input_shape)

x = np.linspace(-0.1, 0.5, num=input_size).reshape(num_inputs, *input_shape)
w = np.linspace(-0.2, 0.3, num=weight_size).reshape(np.prod(input_shape), output_dim)
b = np.linspace(-0.3, 0.1, num=output_dim)

out, _ = affine_forward(x, w, b)
correct_out = np.array([[ 1.49834967,  1.70660132,  1.91485297],
                        [ 3.25553199,  3.5141327,   3.77273342]])

# Compare your output with ours. The error should be around 1e-9.
print 'Testing affine_forward function:'
print 'difference: ', rel_error(out, correct_out)
# Out:
# Testing affine_forward function:
# difference:  9.76984946819e-10

# %%
print(x.shape)
print(w.shape)
print(b.shape)
# Out:
# (2L, 4L, 5L, 6L)
# (120L, 3L)
# (3L,)

# %% [markdown]
# # Affine layer: backward
# Now implement the `affine_backward` function and test your implementation using numeric gradient checking.

# %%
# Test the affine_backward function

x = np.random.randn(10, 2, 3)
w = np.random.randn(6, 5)
b = np.random.randn(5)
dout = np.random.randn(10, 5)

dx_num = eval_numerical_gradient_array(lambda x: affine_forward(x, w, b)[0], x, dout)
dw_num = eval_numerical_gradient_array(lambda w: affine_forward(x, w, b)[0], w, dout)
db_num = eval_numerical_gradient_array(lambda b: affine_forward(x, w, b)[0], b, dout)

_, cache = affine_forward(x, w, b)
dx, dw, db = affine_backward(dout, cache)

# The error should be around 1e-10
print 'Testing affine_backward function:'
print 'dx error: ', rel_error(dx_num, dx)
print 'dw error: ', rel_error(dw_num, dw)
print 'db error: ', rel_error(db_num, db)
# Out:
# Testing affine_backward function:
# dx error:  3.26585592582e-10
# dw error:  6.7464432945e-11
# db error:  3.27556108965e-12

# %% [markdown]
# # ReLU layer: forward
# Implement the forward pass for the ReLU activation function in the `relu_forward` function and test your implementation using the following:

# %%
# Test the relu_forward function

x = np.linspace(-0.5, 0.5, num=12).reshape(3, 4)

out, _ = relu_forward(x)
correct_out = np.array([[ 0.,          0.,          0.,          0.,        ],
                        [ 0.,          0.,          0.04545455,  0.13636364,],
                        [ 0.22727273,  0.31818182,  0.40909091,  0.5,       ]])

# Compare your output with ours. The error should be around 1e-8
print 'Testing relu_forward function:'
print 'difference: ', rel_error(out, correct_out)
# Out:
# Testing relu_forward function:
# difference:  4.99999979802e-08

# %% [markdown]
# # ReLU layer: backward
# Now implement the backward pass for the ReLU activation function in the `relu_backward` function and test your implementation using numeric gradient checking:

# %%
x = np.random.randn(10, 10)
dout = np.random.randn(*x.shape)

dx_num = eval_numerical_gradient_array(lambda x: relu_forward(x)[0], x, dout)

_, cache = relu_forward(x)
dx = relu_backward(dout, cache)

# The error should be around 1e-12
print 'Testing relu_backward function:'
print 'dx error: ', rel_error(dx_num, dx)
# Out:
# Testing relu_backward function:
# dx error:  3.27559107452e-12

# %% [markdown]
# # "Sandwich" layers
# There are some common patterns of layers that are frequently used in neural nets. For example, affine layers are frequently followed by a ReLU nonlinearity. To make these common patterns easy, we define several convenience layers in the file `cs231n/layer_utils.py`.
#
# For now take a look at the `affine_relu_forward` and `affine_relu_backward` functions, and run the following to numerically gradient check the backward pass:

# %%
from cs231n.layer_utils import affine_relu_forward, affine_relu_backward

x = np.random.randn(2, 3, 4)
w = np.random.randn(12, 10)
b = np.random.randn(10)
dout = np.random.randn(2, 10)

out, cache = affine_relu_forward(x, w, b)
dx, dw, db = affine_relu_backward(dout, cache)

dx_num = eval_numerical_gradient_array(lambda x: affine_relu_forward(x, w, b)[0], x, dout)
dw_num = eval_numerical_gradient_array(lambda w: affine_relu_forward(x, w, b)[0], w, dout)
db_num = eval_numerical_gradient_array(lambda b: affine_relu_forward(x, w, b)[0], b, dout)

print 'Testing affine_relu_forward:'
print 'dx error: ', rel_error(dx_num, dx)
print 'dw error: ', rel_error(dw_num, dw)
print 'db error: ', rel_error(db_num, db)
# Out:
# Testing affine_relu_forward:
# dx error:  1.45720178285e-10
# dw error:  4.66901593608e-10
# db error:  1.29635293922e-10

# %% [markdown]
# # Loss layers: Softmax and SVM
# You implemented these loss functions in the last assignment, so we'll give them to you for free here. You should still make sure you understand how they work by looking at the implementations in `cs231n/layers.py`.
#
# You can make sure that the implementations are correct by running the following:

# %%
num_classes, num_inputs = 10, 50
x = 0.001 * np.random.randn(num_inputs, num_classes)
y = np.random.randint(num_classes, size=num_inputs)

dx_num = eval_numerical_gradient(lambda x: svm_loss(x, y)[0], x, verbose=False)
loss, dx = svm_loss(x, y)

# Test svm_loss function. Loss should be around 9 and dx error should be 1e-9
print 'Testing svm_loss:'
print 'loss: ', loss
print 'dx error: ', rel_error(dx_num, dx)

dx_num = eval_numerical_gradient(lambda x: softmax_loss(x, y)[0], x, verbose=False)
loss, dx = softmax_loss(x, y)

# Test softmax_loss function. Loss should be 2.3 and dx error should be 1e-8
print '\nTesting softmax_loss:'
print 'loss: ', loss
print 'dx error: ', rel_error(dx_num, dx)
# Out:
# Testing svm_loss:
# loss:  8.99995962678
# dx error:  1.40215660067e-09
#
# Testing softmax_loss:
# loss:  2.30258150039
# dx error:  8.93987939948e-09

# %%
print(x.shape,y.shape)
# Out:
# ((50L, 10L), (50L,))

# %% [markdown]
# # Two-layer network
# In the previous assignment you implemented a two-layer neural network in a single monolithic class. Now that you have implemented modular versions of the necessary layers, you will reimplement the two layer network using these modular implementations.
#
# Open the file `cs231n/classifiers/fc_net.py` and complete the implementation of the `TwoLayerNet` class. This class will serve as a model for the other networks you will implement in this assignment, so read through it to make sure you understand the API. You can run the cell below to test your implementation.

# %%
N, D, H, C = 3, 5, 50, 7
X = np.random.randn(N, D)
y = np.random.randint(C, size=N)

std = 1e-2
model = TwoLayerNet(input_dim=D, hidden_dim=H, num_classes=C, weight_scale=std)

print 'Testing initialization ... '
W1_std = abs(model.params['W1'].std() - std)
b1 = model.params['b1']
W2_std = abs(model.params['W2'].std() - std)
b2 = model.params['b2']
assert W1_std < std / 10, 'First layer weights do not seem right'
assert np.all(b1 == 0), 'First layer biases do not seem right'
assert W2_std < std / 10, 'Second layer weights do not seem right'
assert np.all(b2 == 0), 'Second layer biases do not seem right'

print 'Testing test-time forward pass ... '
model.params['W1'] = np.linspace(-0.7, 0.3, num=D*H).reshape(D, H)
model.params['b1'] = np.linspace(-0.1, 0.9, num=H)
model.params['W2'] = np.linspace(-0.3, 0.4, num=H*C).reshape(H, C)
model.params['b2'] = np.linspace(-0.9, 0.1, num=C)
X = np.linspace(-5.5, 4.5, num=N*D).reshape(D, N).T
scores = model.loss(X)
correct_scores = np.asarray(
  [[11.53165108,  12.2917344,   13.05181771,  13.81190102,  14.57198434, 15.33206765,  16.09215096],
   [12.05769098,  12.74614105,  13.43459113,  14.1230412,   14.81149128, 15.49994135,  16.18839143],
   [12.58373087,  13.20054771,  13.81736455,  14.43418138,  15.05099822, 15.66781506,  16.2846319 ]])
scores_diff = np.abs(scores - correct_scores).sum()
assert scores_diff < 1e-6, 'Problem with test-time forward pass'

print 'Testing training loss (no regularization)'
y = np.asarray([0, 5, 1])
loss, grads = model.loss(X, y)
correct_loss = 3.4702243556
assert abs(loss - correct_loss) < 1e-10, 'Problem with training-time loss'

model.reg = 1.0
loss, grads = model.loss(X, y)
correct_loss = 26.5948426952
assert abs(loss - correct_loss) < 1e-10, 'Problem with regularization loss'

for reg in [0.0, 0.7]:
  print 'Running numeric gradient check with reg = ', reg
  model.reg = reg
  loss, grads = model.loss(X, y)

  for name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    grad_num = eval_numerical_gradient(f, model.params[name], verbose=False)
    print '%s relative error: %.2e' % (name, rel_error(grad_num, grads[name]))
# Out:
# Testing initialization ...
# Testing test-time forward pass ...
# Testing training loss (no regularization)
# Running numeric gradient check with reg =  0.0
# W1 relative error: 1.83e-08
# W2 relative error: 3.48e-10
# b1 relative error: 6.55e-09
# b2 relative error: 4.33e-10
# Running numeric gradient check with reg =  0.7
# W1 relative error: 2.53e-07
# W2 relative error: 7.98e-08
# b1 relative error: 1.35e-08
# b2 relative error: 9.09e-10

# %% [markdown]
# # Solver
# In the previous assignment, the logic for training models was coupled to the models themselves. Following a more modular design, for this assignment we have split the logic for training models into a separate class.
#
# Open the file `cs231n/solver.py` and read through it to familiarize yourself with the API. After doing so, use a `Solver` instance to train a `TwoLayerNet` that achieves at least `50%` accuracy on the validation set.

# %%
model = TwoLayerNet()
solver = None

##############################################################################
# TODO: Use a Solver instance to train a TwoLayerNet that achieves at least  #
# 50% accuracy on the validation set.                                        #
##############################################################################

num_train = 49000
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

weight_scale = 1e-2
learning_rate = 1e-3

N, D, H, C = num_train, 3*32*32, 200, 10

model = TwoLayerNet(input_dim=D, hidden_dim=H, num_classes=C, weight_scale=std)

solver = Solver(model, small_data,
              update_rule='sgd',
              optim_config={
                'learning_rate': learning_rate,
              },
              lr_decay=0.95,
              num_epochs=10, batch_size=100,
              print_every=100)
solver.train()
##############################################################################
#                             END OF YOUR CODE                               #
##############################################################################
# Out:
# (Iteration 1 / 4900) loss: 5.709899
# (Epoch 0 / 10) train acc: 0.137000; val_acc: 0.086000
# (Iteration 101 / 4900) loss: 2.265878
# (Iteration 201 / 4900) loss: 1.979701
# (Iteration 301 / 4900) loss: 1.543961
# (Iteration 401 / 4900) loss: 1.841593
# (Epoch 1 / 10) train acc: 0.371000; val_acc: 0.357000
# (Iteration 501 / 4900) loss: 1.737916
# (Iteration 601 / 4900) loss: 1.606999
# (Iteration 701 / 4900) loss: 1.720376
# (Iteration 801 / 4900) loss: 1.736042
# (Iteration 901 / 4900) loss: 1.689393
# (Epoch 2 / 10) train acc: 0.451000; val_acc: 0.409000
# (Iteration 1001 / 4900) loss: 1.587675
# (Iteration 1101 / 4900) loss: 1.433539
# (Iteration 1201 / 4900) loss: 1.512627
# (Iteration 1301 / 4900) loss: 1.603915
# (Iteration 1401 / 4900) loss: 1.281239
# (Epoch 3 / 10) train acc: 0.484000; val_acc: 0.429000
# (Iteration 1501 / 4900) loss: 1.448892
# (Iteration 1601 / 4900) loss: 1.424700
# (Iteration 1701 / 4900) loss: 1.665938
# (Iteration 1801 / 4900) loss: 1.559092
# (Iteration 1901 / 4900) loss: 1.472166
# (Epoch 4 / 10) train acc: 0.498000; val_acc: 0.477000
# (Iteration 2001 / 4900) loss: 1.505730
# (Iteration 2101 / 4900) loss: 1.459347
# (Iteration 2201 / 4900) loss: 1.273332
# (Iteration 2301 / 4900) loss: 1.256914
# (Iteration 2401 / 4900) loss: 1.162531
# (Epoch 5 / 10) train acc: 0.516000; val_acc: 0.473000
# (Iteration 2501 / 4900) loss: 1.186434
# (Iteration 2601 / 4900) loss: 1.463140
# (Iteration 2701 / 4900) loss: 1.098070
# (Iteration 2801 / 4900) loss: 1.375615
# (Iteration 2901 / 4900) loss: 1.426460
# (Epoch 6 / 10) train acc: 0.530000; val_acc: 0.453000
# (Iteration 3001 / 4900) loss: 1.247243
# (Iteration 3101 / 4900) loss: 1.356977
# (Iteration 3201 / 4900) loss: 1.367292
# (Iteration 3301 / 4900) loss: 1.036593
# (Iteration 3401 / 4900) loss: 1.258515
# (Epoch 7 / 10) train acc: 0.531000; val_acc: 0.449000
# (Iteration 3501 / 4900) loss: 1.357835
# (Iteration 3601 / 4900) loss: 1.380359
# (Iteration 3701 / 4900) loss: 1.181863
# (Iteration 3801 / 4900) loss: 1.376581
# (Iteration 3901 / 4900) loss: 1.218635
# (Epoch 8 / 10) train acc: 0.590000; val_acc: 0.472000
# (Iteration 4001 / 4900) loss: 1.226632
# (Iteration 4101 / 4900) loss: 1.094272
# (Iteration 4201 / 4900) loss: 1.259775
# (Iteration 4301 / 4900) loss: 1.043653
# (Iteration 4401 / 4900) loss: 1.104288
# (Epoch 9 / 10) train acc: 0.586000; val_acc: 0.476000
# (Iteration 4501 / 4900) loss: 1.367240
# (Iteration 4601 / 4900) loss: 1.008783
# (Iteration 4701 / 4900) loss: 1.073904
# (Iteration 4801 / 4900) loss: 0.759459
# (Epoch 10 / 10) train acc: 0.625000; val_acc: 0.520000

# %%
# Run this cell to visualize training loss and train / val accuracy
plt.figure(figsize=[1,1])
plt.subplot(2, 1, 1)
plt.title('Training loss')
plt.plot(solver.loss_history, 'o')
plt.xlabel('Iteration')

plt.subplot(2, 1, 2)
plt.title('Accuracy')
plt.plot(solver.train_acc_history, '-o', label='train')
plt.plot(solver.val_acc_history, '-o', label='val')
plt.plot([0.5] * len(solver.val_acc_history), 'k--')
plt.xlabel('Epoch')
plt.legend(loc='lower right')
plt.gcf().set_size_inches(15, 12)
plt.show()

# %% [markdown]
# # Multilayer network
# Next you will implement a fully-connected network with an arbitrary number of hidden layers.
#
# Read through the `FullyConnectedNet` class in the file `cs231n/classifiers/fc_net.py`.
#
# Implement the initialization, the forward pass, and the backward pass. For the moment don't worry about implementing dropout or batch normalization; we will add those features soon.

# %% [markdown]
# ## Initial loss and gradient check

# %% [markdown]
# As a sanity check, run the following to check the initial loss and to gradient check the network both with and without regularization. Do the initial losses seem reasonable?
#
# For gradient checking, you should expect to see errors around 1e-6 or less.

# %%
N, D, H1, H2, H3, C = 2, 15, 20, 30, 30, 10
X = np.random.randn(N, D)
y = np.random.randint(C, size=(N,))

for reg in [0, 3.14]:
  print 'Running check with reg = ', reg
  model = FullyConnectedNet([H1, H2, H3], input_dim=D, num_classes=C,
                            reg=reg, weight_scale=5e-2, dtype=np.float64)

  loss, grads = model.loss(X, y)
  print 'Initial loss: ', loss

  for name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    grad_num = eval_numerical_gradient(f, model.params[name], verbose=False, h=1e-5)
    print '%s relative error: %.2e' % (name, rel_error(grad_num, grads[name]))
# Out:
# Running check with reg =  0
# Initial loss:  2.3020449811
# W1 relative error: 1.47e-05
# W2 relative error: 8.57e-06
# W3 relative error: 5.46e-06
# W4 relative error: 1.14e-06
# b1 relative error: 7.36e-08
# b2 relative error: 4.24e-07
# b3 relative error: 3.55e-09
# b4 relative error: 1.87e-10
# Running check with reg =  3.14
# Initial loss:  10.5154897957
# W1 relative error: 4.85e-07
# W2 relative error: 2.56e-07
# W3 relative error: 3.81e-07
# W4 relative error: 3.23e-08
# b1 relative error: 7.25e-07
# b2 relative error: 1.35e-08
# b3 relative error: 8.19e-08
# b4 relative error: 3.88e-10

# %% [markdown]
# As another sanity check, make sure you can overfit a small dataset of 50 images. First we will try a three-layer network with 100 units in each hidden layer. You will need to tweak the learning rate and initialization scale, but you should be able to overfit and achieve 100% training accuracy within 20 epochs.

# %%
# TODO: Use a three-layer Net to overfit 50 training examples.

num_train = 50
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

weight_scale = 1e-2
learning_rate = 1e-2
model = FullyConnectedNet([100, 100],
              weight_scale=weight_scale, dtype=np.float64)
solver = Solver(model, small_data,
                print_every=10, num_epochs=20, batch_size=25,
                update_rule='sgd',
                optim_config={
                  'learning_rate': learning_rate,
                }
         )
solver.train()

plt.plot(solver.loss_history, 'o')
plt.title('Training loss history')
plt.xlabel('Iteration')
plt.ylabel('Training loss')
plt.show()
# Out:
# (Iteration 1 / 40) loss: 2.284122
# (Epoch 0 / 20) train acc: 0.180000; val_acc: 0.081000
# (Epoch 1 / 20) train acc: 0.300000; val_acc: 0.080000
# (Epoch 2 / 20) train acc: 0.440000; val_acc: 0.121000
# (Epoch 3 / 20) train acc: 0.440000; val_acc: 0.116000
# (Epoch 4 / 20) train acc: 0.540000; val_acc: 0.147000
# (Epoch 5 / 20) train acc: 0.700000; val_acc: 0.160000
# (Iteration 11 / 40) loss: 0.746745
# (Epoch 6 / 20) train acc: 0.680000; val_acc: 0.186000
# (Epoch 7 / 20) train acc: 0.820000; val_acc: 0.184000
# (Epoch 8 / 20) train acc: 0.900000; val_acc: 0.209000
# (Epoch 9 / 20) train acc: 0.800000; val_acc: 0.157000
# (Epoch 10 / 20) train acc: 0.900000; val_acc: 0.192000
# (Iteration 21 / 40) loss: 0.233735
# (Epoch 11 / 20) train acc: 1.000000; val_acc: 0.199000
# (Epoch 12 / 20) train acc: 0.980000; val_acc: 0.204000
# (Epoch 13 / 20) train acc: 1.000000; val_acc: 0.198000
# (Epoch 14 / 20) train acc: 0.980000; val_acc: 0.202000
# (Epoch 15 / 20) train acc: 1.000000; val_acc: 0.198000
# (Iteration 31 / 40) loss: 0.062061
# (Epoch 16 / 20) train acc: 1.000000; val_acc: 0.198000
# (Epoch 17 / 20) train acc: 1.000000; val_acc: 0.197000
# (Epoch 18 / 20) train acc: 1.000000; val_acc: 0.188000
# (Epoch 19 / 20) train acc: 1.000000; val_acc: 0.200000
# (Epoch 20 / 20) train acc: 1.000000; val_acc: 0.194000

# %% [markdown]
# Now try to use a five-layer network with 100 units on each layer to overfit 50 training examples. Again you will have to adjust the learning rate and weight initialization, but you should be able to achieve 100% training accuracy within 20 epochs.

# %%
# TODO: Use a five-layer Net to overfit 50 training examples.

num_train = 50
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

learning_rate = 1e-2
weight_scale = 1e-3
model = FullyConnectedNet([100, 100, 100, 100],
                weight_scale=weight_scale, dtype=np.float64)
solver = Solver(model, small_data,
                print_every=10, num_epochs=20, batch_size=25,
                update_rule='sgd',
                optim_config={
                  'learning_rate': learning_rate,
                }
         )
solver.train()

plt.plot(solver.loss_history, 'o')
plt.title('Training loss history')
plt.xlabel('Iteration')
plt.ylabel('Training loss')
plt.show()
# Out:
# (Iteration 1 / 40) loss: 2.302585
# (Epoch 0 / 20) train acc: 0.100000; val_acc: 0.102000
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 2 / 20) train acc: 0.120000; val_acc: 0.105000
# (Epoch 3 / 20) train acc: 0.120000; val_acc: 0.105000
# (Epoch 4 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 5 / 20) train acc: 0.160000; val_acc: 0.079000
# (Iteration 11 / 40) loss: 2.302084
# (Epoch 6 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 7 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 8 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 9 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 10 / 20) train acc: 0.160000; val_acc: 0.079000
# (Iteration 21 / 40) loss: 2.299332
# (Epoch 11 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 12 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 13 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 14 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 15 / 20) train acc: 0.160000; val_acc: 0.079000
# (Iteration 31 / 40) loss: 2.296653
# (Epoch 16 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 17 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 18 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 19 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 20 / 20) train acc: 0.160000; val_acc: 0.079000

# %%
def run_solver(data):
    learning_rate = 10**(-np.random.uniform(low=2,high=4,size=10))
    weight_scale = 10**(-np.random.uniform(low=1,high=3,size=10))
    max_acc=0
    best_lrate=0
    best_wscale=0
    for learning,weight in zip(learning_rate,weight_scale):
        model = FullyConnectedNet([100, 100, 100, 100],
                        weight_scale=weight, dtype=np.float64)
        solver = Solver(model, data,
                        print_every=10, num_epochs=20, batch_size=25,
                        update_rule='sgd',
                        optim_config={
                          'learning_rate': learning,
                        },
                        verbose=False
                 )
        solver.train()
        if np.max(solver.train_acc_history)>max_acc:
            max_acc=np.max(solver.train_acc_history)
            best_lrate=learning
            best_wscale=weight
            best_solver=solver
    
    return best_solver,(max_acc,best_lrate,best_wscale)

# %%
best_solver,max_score=run_solver(small_data)

# %%
print('Max accuracy:',max_score)

plt.figure(figsize=[1,1])
plt.subplot(2, 1, 1)
plt.title('Training loss')
plt.plot(best_solver.loss_history, 'o')
plt.xlabel('Iteration')

plt.subplot(2, 1, 2)
plt.title('Accuracy')
plt.plot(best_solver.train_acc_history, '-o', label='train')
plt.plot(best_solver.val_acc_history, '-o', label='val')
plt.plot([0.5] * len(best_solver.val_acc_history), 'k--')
plt.xlabel('Epoch')
plt.legend(loc='lower right')
plt.gcf().set_size_inches(15, 12)
plt.show()
# Out:
# ('Max accuracy:', (1.0, 0.00036652684681788832, 0.088813383730424633))

# %% [markdown]
# # Inline question:
# Did you notice anything about the comparative difficulty of training the three-layer net vs training the five layer net?
#
# # Answer:
# Yes, it is harder. (Actually I was training four-layer net previously. But even that one is easier to train than the fiver-layer net.)

# %% [markdown]
# # Update rules
# So far we have used vanilla stochastic gradient descent (SGD) as our update rule. More sophisticated update rules can make it easier to train deep networks. We will implement a few of the most commonly used update rules and compare them to vanilla SGD.

# %% [markdown]
# # SGD+Momentum
# Stochastic gradient descent with momentum is a widely used update rule that tends to make deep networks converge faster than vanilla stochstic gradient descent.
#
# Open the file `cs231n/optim.py` and read the documentation at the top of the file to make sure you understand the API. Implement the SGD+momentum update rule in the function `sgd_momentum` and run the following to check your implementation. You should see errors less than 1e-8.

# %%
from cs231n.optim import sgd_momentum

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
v = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)

config = {'learning_rate': 1e-3, 'velocity': v}
next_w, _ = sgd_momentum(w, dw, config=config)

expected_next_w = np.asarray([
  [ 0.1406,      0.20738947,  0.27417895,  0.34096842,  0.40775789],
  [ 0.47454737,  0.54133684,  0.60812632,  0.67491579,  0.74170526],
  [ 0.80849474,  0.87528421,  0.94207368,  1.00886316,  1.07565263],
  [ 1.14244211,  1.20923158,  1.27602105,  1.34281053,  1.4096    ]])
expected_velocity = np.asarray([
  [ 0.5406,      0.55475789,  0.56891579, 0.58307368,  0.59723158],
  [ 0.61138947,  0.62554737,  0.63970526,  0.65386316,  0.66802105],
  [ 0.68217895,  0.69633684,  0.71049474,  0.72465263,  0.73881053],
  [ 0.75296842,  0.76712632,  0.78128421,  0.79544211,  0.8096    ]])

print 'next_w error: ', rel_error(next_w, expected_next_w)
print 'velocity error: ', rel_error(expected_velocity, config['velocity'])
# Out:
# next_w error:  8.88234703351e-09
# velocity error:  4.26928774328e-09

# %% [markdown]
# Once you have done so, run the following to train a six-layer network with both SGD and SGD+momentum. You should see the SGD+momentum update rule converge faster.

# %%
num_train = 4000
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

solvers = {}

for update_rule in ['sgd','sgd_momentum', 'sgd_Nesterovmom']:
  print 'running with ', update_rule
  model = FullyConnectedNet([100, 100, 100, 100, 100], weight_scale=5e-2)

  solver = Solver(model, small_data,
                  num_epochs=5, batch_size=100,
                  update_rule=update_rule,
                  optim_config={
                    'learning_rate': 1e-2,
                  },
                  verbose=True)
  solvers[update_rule] = solver
  solver.train()
  print

plt.subplot(3, 1, 1)
plt.title('Training loss')
plt.xlabel('Iteration')

plt.subplot(3, 1, 2)
plt.title('Training accuracy')
plt.xlabel('Epoch')

plt.subplot(3, 1, 3)
plt.title('Validation accuracy')
plt.xlabel('Epoch')

for update_rule, solver in solvers.iteritems():
  plt.subplot(3, 1, 1)
  plt.plot(solver.loss_history, 'o', label=update_rule)
  
  plt.subplot(3, 1, 2)
  plt.plot(solver.train_acc_history, '-o', label=update_rule)

  plt.subplot(3, 1, 3)
  plt.plot(solver.val_acc_history, '-o', label=update_rule)
  
for i in [1, 2, 3]:
  plt.subplot(3, 1, i)
  plt.legend(loc='upper center', ncol=4)
plt.gcf().set_size_inches(15, 15)
plt.show()
# Out:
# running with  sgd
# (Iteration 1 / 200) loss: 2.504633
# (Epoch 0 / 5) train acc: 0.113000; val_acc: 0.125000
# (Iteration 11 / 200) loss: 2.153485
# (Iteration 21 / 200) loss: 2.009435
# (Iteration 31 / 200) loss: 2.086021
# (Epoch 1 / 5) train acc: 0.294000; val_acc: 0.248000
# (Iteration 41 / 200) loss: 1.950760
# (Iteration 51 / 200) loss: 1.892070
# (Iteration 61 / 200) loss: 1.974121
# (Iteration 71 / 200) loss: 1.981964
# (Epoch 2 / 5) train acc: 0.332000; val_acc: 0.278000
# (Iteration 81 / 200) loss: 1.920060
# (Iteration 91 / 200) loss: 2.065070
# (Iteration 101 / 200) loss: 1.748304
# (Iteration 111 / 200) loss: 1.847615
# (Epoch 3 / 5) train acc: 0.367000; val_acc: 0.315000
# (Iteration 121 / 200) loss: 1.709427
# (Iteration 131 / 200) loss: 1.743219
# (Iteration 141 / 200) loss: 1.644964
# (Iteration 151 / 200) loss: 1.663654
# (Epoch 4 / 5) train acc: 0.387000; val_acc: 0.337000
# (Iteration 161 / 200) loss: 1.670113
# (Iteration 171 / 200) loss: 1.443152
# (Iteration 181 / 200) loss: 1.733327
# (Iteration 191 / 200) loss: 1.581570
# (Epoch 5 / 5) train acc: 0.409000; val_acc: 0.334000
#
# running with  sgd_momentum
# (Iteration 1 / 200) loss: 2.588877
# (Epoch 0 / 5) train acc: 0.134000; val_acc: 0.101000
# (Iteration 11 / 200) loss: 2.165748
# (Iteration 21 / 200) loss: 2.095656
# (Iteration 31 / 200) loss: 1.949682
# (Epoch 1 / 5) train acc: 0.350000; val_acc: 0.319000
# (Iteration 41 / 200) loss: 1.925788
# (Iteration 51 / 200) loss: 1.652948
# (Iteration 61 / 200) loss: 1.866848
# (Iteration 71 / 200) loss: 1.515591
# (Epoch 2 / 5) train acc: 0.419000; val_acc: 0.316000
# (Iteration 81 / 200) loss: 1.751421
# (Iteration 91 / 200) loss: 1.611745
# (Iteration 101 / 200) loss: 1.633302
# (Iteration 111 / 200) loss: 1.374378
# (Epoch 3 / 5) train acc: 0.448000; val_acc: 0.359000
# (Iteration 121 / 200) loss: 1.425727
# (Iteration 131 / 200) loss: 1.693438
# (Iteration 141 / 200) loss: 1.366597
# (Iteration 151 / 200) loss: 1.521823
# (Epoch 4 / 5) train acc: 0.514000; val_acc: 0.361000
# (Iteration 161 / 200) loss: 1.573646
# (Iteration 171 / 200) loss: 1.620457
# (Iteration 181 / 200) loss: 1.515276
# (Iteration 191 / 200) loss: 1.380647
# (Epoch 5 / 5) train acc: 0.496000; val_acc: 0.336000
#
# running with  sgd_Nesterovmom
# (Iteration 1 / 200) loss: 2.663932
# (Epoch 0 / 5) train acc: 0.115000; val_acc: 0.134000
# (Iteration 11 / 200) loss: 2.025229
# (Iteration 21 / 200) loss: 1.793672
# (Iteration 31 / 200) loss: 1.808189
# (Epoch 1 / 5) train acc: 0.350000; val_acc: 0.287000
# (Iteration 41 / 200) loss: 1.758778
# (Iteration 51 / 200) loss: 1.744689
# (Iteration 61 / 200) loss: 1.628885
# (Iteration 71 / 200) loss: 1.678764
# (Epoch 2 / 5) train acc: 0.430000; val_acc: 0.332000
# (Iteration 81 / 200) loss: 1.629994
# (Iteration 91 / 200) loss: 1.415237
# (Iteration 101 / 200) loss: 1.539440
# (Iteration 111 / 200) loss: 1.312476
# (Epoch 3 / 5) train acc: 0.493000; val_acc: 0.324000
# (Iteration 121 / 200) loss: 1.331387
# (Iteration 131 / 200) loss: 1.255330
# (Iteration 141 / 200) loss: 1.403614
# (Iteration 151 / 200) loss: 1.633192
# (Epoch 4 / 5) train acc: 0.517000; val_acc: 0.360000
# (Iteration 161 / 200) loss: 1.251689
# (Iteration 171 / 200) loss: 1.248328
# (Iteration 181 / 200) loss: 1.464107
# (Iteration 191 / 200) loss: 1.140357
# (Epoch 5 / 5) train acc: 0.595000; val_acc: 0.360000

# %% [markdown]
# # RMSProp and Adam
# RMSProp [1] and Adam [2] are update rules that set per-parameter learning rates by using a running average of the second moments of gradients.
#
# In the file `cs231n/optim.py`, implement the RMSProp update rule in the `rmsprop` function and implement the Adam update rule in the `adam` function, and check your implementations using the tests below.
#
# [1] Tijmen Tieleman and Geoffrey Hinton. "Lecture 6.5-rmsprop: Divide the gradient by a running average of its recent magnitude." COURSERA: Neural Networks for Machine Learning 4 (2012).
#
# [2] Diederik Kingma and Jimmy Ba, "Adam: A Method for Stochastic Optimization", ICLR 2015.

# %%
# Test RMSProp implementation; you should see errors less than 1e-7
from cs231n.optim import rmsprop

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
cache = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)

config = {'learning_rate': 1e-2, 'cache': cache}
next_w, _ = rmsprop(w, dw, config=config)

expected_next_w = np.asarray([
  [-0.39223849, -0.34037513, -0.28849239, -0.23659121, -0.18467247],
  [-0.132737,   -0.08078555, -0.02881884,  0.02316247,  0.07515774],
  [ 0.12716641,  0.17918792,  0.23122175,  0.28326742,  0.33532447],
  [ 0.38739248,  0.43947102,  0.49155973,  0.54365823,  0.59576619]])
expected_cache = np.asarray([
  [ 0.5976,      0.6126277,   0.6277108,   0.64284931,  0.65804321],
  [ 0.67329252,  0.68859723,  0.70395734,  0.71937285,  0.73484377],
  [ 0.75037008,  0.7659518,   0.78158892,  0.79728144,  0.81302936],
  [ 0.82883269,  0.84469141,  0.86060554,  0.87657507,  0.8926    ]])

print 'next_w error: ', rel_error(expected_next_w, next_w)
print 'cache error: ', rel_error(expected_cache, config['cache'])
# Out:
# next_w error:  9.52468751104e-08
# cache error:  2.64779558072e-09

# %%
# Test Adam implementation; you should see errors around 1e-7 or less
from cs231n.optim import adam

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
m = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)
v = np.linspace(0.7, 0.5, num=N*D).reshape(N, D)

config = {'learning_rate': 1e-2, 'm': m, 'v': v, 't': 5}
next_w, _ = adam(w, dw, config=config)

expected_next_w = np.asarray([
  [-0.40094747, -0.34836187, -0.29577703, -0.24319299, -0.19060977],
  [-0.1380274,  -0.08544591, -0.03286534,  0.01971428,  0.0722929],
  [ 0.1248705,   0.17744702,  0.23002243,  0.28259667,  0.33516969],
  [ 0.38774145,  0.44031188,  0.49288093,  0.54544852,  0.59801459]])
expected_v = np.asarray([
  [ 0.69966,     0.68908382,  0.67851319,  0.66794809,  0.65738853,],
  [ 0.64683452,  0.63628604,  0.6257431,   0.61520571,  0.60467385,],
  [ 0.59414753,  0.58362676,  0.57311152,  0.56260183,  0.55209767,],
  [ 0.54159906,  0.53110598,  0.52061845,  0.51013645,  0.49966,   ]])
expected_m = np.asarray([
  [ 0.48,        0.49947368,  0.51894737,  0.53842105,  0.55789474],
  [ 0.57736842,  0.59684211,  0.61631579,  0.63578947,  0.65526316],
  [ 0.67473684,  0.69421053,  0.71368421,  0.73315789,  0.75263158],
  [ 0.77210526,  0.79157895,  0.81105263,  0.83052632,  0.85      ]])

print 'next_w error: ', rel_error(expected_next_w, next_w)
print 'v error: ', rel_error(expected_v, config['v'])
print 'm error: ', rel_error(expected_m, config['m'])
# Out:
# next_w error:  1.13956917985e-07
# v error:  4.20831403811e-09
# m error:  4.21496319311e-09

# %% [markdown]
# Once you have debugged your RMSProp and Adam implementations, run the following to train a pair of deep networks using these new update rules:

# %%
learning_rates = {'rmsprop': 1e-4,'rmsprop_Jiyao': 1e-4,'adagrad':1e-4, 'adam': 1e-3}
for update_rule in ['adam','adagrad', 'rmsprop','rmsprop_Jiyao']:
  print 'running with ', update_rule
  model = FullyConnectedNet([100, 100, 100, 100, 100], weight_scale=5e-2)

  solver = Solver(model, small_data,
                  num_epochs=5, batch_size=100,
                  update_rule=update_rule,
                  optim_config={
                    'learning_rate': learning_rates[update_rule]
                  },
                  verbose=True)
  solvers[update_rule] = solver
  solver.train()
  print

plt.subplot(3, 1, 1)
plt.title('Training loss')
plt.xlabel('Iteration')

plt.subplot(3, 1, 2)
plt.title('Training accuracy')
plt.xlabel('Epoch')

plt.subplot(3, 1, 3)
plt.title('Validation accuracy')
plt.xlabel('Epoch')

for update_rule, solver in solvers.iteritems():
  plt.subplot(3, 1, 1)
  plt.plot(solver.loss_history, 'o', label=update_rule)
  
  plt.subplot(3, 1, 2)
  plt.plot(solver.train_acc_history, '-o', label=update_rule)

  plt.subplot(3, 1, 3)
  plt.plot(solver.val_acc_history, '-o', label=update_rule)
  
for i in [1, 2, 3]:
  plt.subplot(3, 1, i)
  plt.legend(loc='lower center', ncol=4)
plt.gcf().set_size_inches(15, 15)
plt.show()
# Out:
# running with  adam
# (Iteration 1 / 200) loss: 2.904987
# (Epoch 0 / 5) train acc: 0.124000; val_acc: 0.117000
# (Iteration 11 / 200) loss: 2.230919
# (Iteration 21 / 200) loss: 1.885736
# (Iteration 31 / 200) loss: 2.051451
# (Epoch 1 / 5) train acc: 0.365000; val_acc: 0.298000
# (Iteration 41 / 200) loss: 1.941110
# (Iteration 51 / 200) loss: 1.588555
# (Iteration 61 / 200) loss: 1.640745
# (Iteration 71 / 200) loss: 1.687982
# (Epoch 2 / 5) train acc: 0.408000; val_acc: 0.339000
# (Iteration 81 / 200) loss: 1.585449
# (Iteration 91 / 200) loss: 1.611342
# (Iteration 101 / 200) loss: 1.444658
# (Iteration 111 / 200) loss: 1.654249
# (Epoch 3 / 5) train acc: 0.479000; val_acc: 0.354000
# (Iteration 121 / 200) loss: 1.504347
# (Iteration 131 / 200) loss: 1.479638
# (Iteration 141 / 200) loss: 1.348628
# (Iteration 151 / 200) loss: 1.272800
# (Epoch 4 / 5) train acc: 0.543000; val_acc: 0.362000
# (Iteration 161 / 200) loss: 1.292857
# (Iteration 171 / 200) loss: 1.202692
# (Iteration 181 / 200) loss: 1.312029
# (Iteration 191 / 200) loss: 1.103937
# (Epoch 5 / 5) train acc: 0.561000; val_acc: 0.383000
#
# running with  adagrad
# (Iteration 1 / 200) loss: 2.281003
# (Epoch 0 / 5) train acc: 0.135000; val_acc: 0.120000
# (Iteration 11 / 200) loss: 2.362663
# (Iteration 21 / 200) loss: 2.188314
# (Iteration 31 / 200) loss: 2.265809
# (Epoch 1 / 5) train acc: 0.178000; val_acc: 0.164000
# (Iteration 41 / 200) loss: 2.241532
# (Iteration 51 / 200) loss: 2.219202
# (Iteration 61 / 200) loss: 2.189716
# (Iteration 71 / 200) loss: 2.153772
# (Epoch 2 / 5) train acc: 0.210000; val_acc: 0.179000
# (Iteration 81 / 200) loss: 2.184326
# (Iteration 91 / 200) loss: 2.233046
# (Iteration 101 / 200) loss: 2.107402
# (Iteration 111 / 200) loss: 2.152497
# (Epoch 3 / 5) train acc: 0.204000; val_acc: 0.195000
# (Iteration 121 / 200) loss: 2.147400
# (Iteration 131 / 200) loss: 2.173694
# (Iteration 141 / 200) loss: 2.154980
# (Iteration 151 / 200) loss: 2.065225
# (Epoch 4 / 5) train acc: 0.257000; val_acc: 0.210000
# (Iteration 161 / 200) loss: 2.117591
# (Iteration 171 / 200) loss: 2.155476
# (Iteration 181 / 200) loss: 2.085627
# (Iteration 191 / 200) loss: 2.019686
# (Epoch 5 / 5) train acc: 0.254000; val_acc: 0.217000
#
# running with  rmsprop
# (Iteration 1 / 200) loss: 2.892807
# (Epoch 0 / 5) train acc: 0.126000; val_acc: 0.127000
# (Iteration 11 / 200) loss: 2.148291
# (Iteration 21 / 200) loss: 2.005005
# (Iteration 31 / 200) loss: 1.796502
# (Epoch 1 / 5) train acc: 0.399000; val_acc: 0.306000
# (Iteration 41 / 200) loss: 1.915895
# (Iteration 51 / 200) loss: 1.936233
# (Iteration 61 / 200) loss: 1.775067
# (Iteration 71 / 200) loss: 1.642734
# (Epoch 2 / 5) train acc: 0.458000; val_acc: 0.324000
# (Iteration 81 / 200) loss: 1.585126
# (Iteration 91 / 200) loss: 1.628694
# (Iteration 101 / 200) loss: 1.717087
# (Iteration 111 / 200) loss: 1.591966
# (Epoch 3 / 5) train acc: 0.468000; val_acc: 0.360000
# (Iteration 121 / 200) loss: 1.568280
# (Iteration 131 / 200) loss: 1.656236
# (Iteration 141 / 200) loss: 1.540759
# (Iteration 151 / 200) loss: 1.448168
# (Epoch 4 / 5) train acc: 0.512000; val_acc: 0.359000
# (Iteration 161 / 200) loss: 1.347374
# (Iteration 171 / 200) loss: 1.404749
# (Iteration 181 / 200) loss: 1.377063
# (Iteration 191 / 200) loss: 1.296655
# (Epoch 5 / 5) train acc: 0.523000; val_acc: 0.368000
#
# running with  rmsprop_Jiyao
# (Iteration 1 / 200) loss: 3.059955
# (Epoch 0 / 5) train acc: 0.118000; val_acc: 0.122000
# (Iteration 11 / 200) loss: 2.145101
# (Iteration 21 / 200) loss: 1.969700
# (Iteration 31 / 200) loss: 1.884188
# (Epoch 1 / 5) train acc: 0.361000; val_acc: 0.281000
# (Iteration 41 / 200) loss: 1.714422
# (Iteration 51 / 200) loss: 1.807046
# (Iteration 61 / 200) loss: 1.718116
# (Iteration 71 / 200) loss: 1.548108
# (Epoch 2 / 5) train acc: 0.441000; val_acc: 0.326000
# (Iteration 81 / 200) loss: 1.690036
# (Iteration 91 / 200) loss: 1.669460
# (Iteration 101 / 200) loss: 1.532316
# (Iteration 111 / 200) loss: 1.574290
# (Epoch 3 / 5) train acc: 0.484000; val_acc: 0.346000
# (Iteration 121 / 200) loss: 1.589906
# (Iteration 131 / 200) loss: 1.399841
# (Iteration 141 / 200) loss: 1.557154
# (Iteration 151 / 200) loss: 1.394101
# (Epoch 4 / 5) train acc: 0.544000; val_acc: 0.359000
# (Iteration 161 / 200) loss: 1.278670
# (Iteration 171 / 200) loss: 1.287842
# (Iteration 181 / 200) loss: 1.473604
# (Iteration 191 / 200) loss: 1.475544
# (Epoch 5 / 5) train acc: 0.549000; val_acc: 0.360000

# %% [markdown]
# # Train a good model!
# Train the best fully-connected model that you can on CIFAR-10, storing your best model in the `best_model` variable. We require you to get at least 50% accuracy on the validation set using a fully-connected net.
#
# If you are careful it should be possible to get accuracies above 55%, but we don't require it for this part and won't assign extra credit for doing so. Later in the assignment we will ask you to train the best convolutional network that you can on CIFAR-10, and we would prefer that you spend your effort working on convolutional nets rather than fully-connected nets.
#
# You might find it useful to complete the `BatchNormalization.ipynb` and `Dropout.ipynb` notebooks before completing this part, since those techniques can help you train powerful models.

# %%
best_model = None

num_train = 4900
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}
best_parameter={}
best_parameter['val'] = 0
################################################################################
# TODO: Train the best FullyConnectedNet that you can on CIFAR-10. You might   #
# batch normalization and dropout useful. Store your best model in the         #
# best_model variable.                                                         #
################################################################################
solvers={}
learning_choices=10**(-np.random.uniform(low=1,high=4,size=10))
weight_choices=10**(-np.random.uniform(low=1,high=4,size=10))
dropout_choices=[0, 0.75]
for i,learning_rate in enumerate(learning_choices):
    for j,weight in  enumerate(weight_choices):
        for k,dropout in  enumerate(dropout_choices):
            name='l'+str(i+1)+'w'+str(j+1)+'d'+str(k+1)
            print 'running with learning_rate {:.2E}, weight scale {:.2E}, dropout {}'.format(learning_rate,weight, dropout)
            model = FullyConnectedNet([100, 100, 100, 100, 100], 
                                      weight_scale=weight,dropout=dropout,use_batchnorm=True)

            solver = Solver(model, small_data,
                      num_epochs=5, batch_size=100,
                      update_rule='adam',
                      optim_config={
                        'learning_rate': learning_rate
                      },
                      verbose=False, print_every=2000)
            solvers[name] = solver
            solver.train()
            print

            val = np.max(solver.val_acc_history)

            print 'Validity: ', val
            if val > best_parameter['val']:
                best_model = model
                best_parameter['val']=val
                best_parameter['learning_rate'] = learning_rate
                best_parameter['weight'] = weight
                best_parameter['dropout'] = dropout


################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# running with learning_rate 5.41E-02, weight scale 2.74E-02, dropout 0
#
# Validity:  0.344
# running with learning_rate 5.41E-02, weight scale 2.74E-02, dropout 0.75
#
# Validity:  0.278
# running with learning_rate 5.41E-02, weight scale 2.87E-02, dropout 0
#
# Validity:  0.35
# running with learning_rate 5.41E-02, weight scale 2.87E-02, dropout 0.75
#
# Validity:  0.262
# running with learning_rate 5.41E-02, weight scale 1.37E-04, dropout 0
#
# Validity:  0.356
# running with learning_rate 5.41E-02, weight scale 1.37E-04, dropout 0.75
#
# Validity:  0.266
# running with learning_rate 5.41E-02, weight scale 1.09E-04, dropout 0
#
# Validity:  0.343
# running with learning_rate 5.41E-02, weight scale 1.09E-04, dropout 0.75
#
# Validity:  0.281
# running with learning_rate 5.41E-02, weight scale 7.69E-03, dropout 0
#
# Validity:  0.346
# running with learning_rate 5.41E-02, weight scale 7.69E-03, dropout 0.75
#
# Validity:  0.284
# running with learning_rate 5.41E-02, weight scale 5.08E-04, dropout 0
#
# Validity:  0.346
# running with learning_rate 5.41E-02, weight scale 5.08E-04, dropout 0.75
#
# Validity:  0.285
# running with learning_rate 5.41E-02, weight scale 2.77E-04, dropout 0
#
# Validity:  0.354
# running with learning_rate 5.41E-02, weight scale 2.77E-04, dropout 0.75
#
# Validity:  0.26
# running with learning_rate 5.41E-02, weight scale 2.35E-04, dropout 0
#
# Validity:  0.372
# running with learning_rate 5.41E-02, weight scale 2.35E-04, dropout 0.75
#
# Validity:  0.26
# running with learning_rate 5.41E-02, weight scale 5.71E-03, dropout 0
#
# Validity:  0.331
# running with learning_rate 5.41E-02, weight scale 5.71E-03, dropout 0.75
#
# Validity:  0.29
# running with learning_rate 5.41E-02, weight scale 5.06E-02, dropout 0
#
# Validity:  0.351
# running with learning_rate 5.41E-02, weight scale 5.06E-02, dropout 0.75
#
# Validity:  0.274
# running with learning_rate 1.77E-02, weight scale 2.74E-02, dropout 0
#
# Validity:  0.378
# running with learning_rate 1.77E-02, weight scale 2.74E-02, dropout 0.75
#
# Validity:  0.363
# running with learning_rate 1.77E-02, weight scale 2.87E-02, dropout 0
#
# Validity:  0.374
# running with learning_rate 1.77E-02, weight scale 2.87E-02, dropout 0.75
#
# Validity:  0.357
# running with learning_rate 1.77E-02, weight scale 1.37E-04, dropout 0
#
# Validity:  0.379
# running with learning_rate 1.77E-02, weight scale 1.37E-04, dropout 0.75
#
# Validity:  0.327
# running with learning_rate 1.77E-02, weight scale 1.09E-04, dropout 0
#
# Validity:  0.372
# running with learning_rate 1.77E-02, weight scale 1.09E-04, dropout 0.75
#
# Validity:  0.363
# running with learning_rate 1.77E-02, weight scale 7.69E-03, dropout 0
#
# Validity:  0.361
# running with learning_rate 1.77E-02, weight scale 7.69E-03, dropout 0.75
#
# Validity:  0.364
# running with learning_rate 1.77E-02, weight scale 5.08E-04, dropout 0
#
# Validity:  0.39
# running with learning_rate 1.77E-02, weight scale 5.08E-04, dropout 0.75
#
# Validity:  0.342
# running with learning_rate 1.77E-02, weight scale 2.77E-04, dropout 0
#
# Validity:  0.385
# running with learning_rate 1.77E-02, weight scale 2.77E-04, dropout 0.75
#
# Validity:  0.367
# running with learning_rate 1.77E-02, weight scale 2.35E-04, dropout 0
#
# Validity:  0.384
# running with learning_rate 1.77E-02, weight scale 2.35E-04, dropout 0.75
#
# Validity:  0.383
# running with learning_rate 1.77E-02, weight scale 5.71E-03, dropout 0
#
# Validity:  0.374
# running with learning_rate 1.77E-02, weight scale 5.71E-03, dropout 0.75
#
# Validity:  0.361
# running with learning_rate 1.77E-02, weight scale 5.06E-02, dropout 0
#
# Validity:  0.383
# running with learning_rate 1.77E-02, weight scale 5.06E-02, dropout 0.75
#
# Validity:  0.356
# running with learning_rate 2.54E-02, weight scale 2.74E-02, dropout 0
#
# Validity:  0.373
# running with learning_rate 2.54E-02, weight scale 2.74E-02, dropout 0.75
#
# Validity:  0.343
# running with learning_rate 2.54E-02, weight scale 2.87E-02, dropout 0
#
# Validity:  0.38
# running with learning_rate 2.54E-02, weight scale 2.87E-02, dropout 0.75
#
# Validity:  0.356
# running with learning_rate 2.54E-02, weight scale 1.37E-04, dropout 0
#
# Validity:  0.362
# running with learning_rate 2.54E-02, weight scale 1.37E-04, dropout 0.75
#
# Validity:  0.323
# running with learning_rate 2.54E-02, weight scale 1.09E-04, dropout 0
#
# Validity:  0.378
# running with learning_rate 2.54E-02, weight scale 1.09E-04, dropout 0.75
#
# Validity:  0.348
# running with learning_rate 2.54E-02, weight scale 7.69E-03, dropout 0
#
# Validity:  0.376
# running with learning_rate 2.54E-02, weight scale 7.69E-03, dropout 0.75
#
# Validity:  0.364
# running with learning_rate 2.54E-02, weight scale 5.08E-04, dropout 0
#
# Validity:  0.376
# running with learning_rate 2.54E-02, weight scale 5.08E-04, dropout 0.75
#
# Validity:  0.341
# running with learning_rate 2.54E-02, weight scale 2.77E-04, dropout 0
#
# Validity:  0.368
# running with learning_rate 2.54E-02, weight scale 2.77E-04, dropout 0.75
#
# Validity:  0.355
# running with learning_rate 2.54E-02, weight scale 2.35E-04, dropout 0
#
# Validity:  0.377
# running with learning_rate 2.54E-02, weight scale 2.35E-04, dropout 0.75
#
# Validity:  0.327
# running with learning_rate 2.54E-02, weight scale 5.71E-03, dropout 0
#
# Validity:  0.374
# running with learning_rate 2.54E-02, weight scale 5.71E-03, dropout 0.75
#
# Validity:  0.339
# running with learning_rate 2.54E-02, weight scale 5.06E-02, dropout 0
#
# Validity:  0.386
# running with learning_rate 2.54E-02, weight scale 5.06E-02, dropout 0.75
#
# Validity:  0.328
# running with learning_rate 4.41E-04, weight scale 2.74E-02, dropout 0
#
# Validity:  0.413
# running with learning_rate 4.41E-04, weight scale 2.74E-02, dropout 0.75
#
# Validity:  0.373
# running with learning_rate 4.41E-04, weight scale 2.87E-02, dropout 0
#
# Validity:  0.4
# running with learning_rate 4.41E-04, weight scale 2.87E-02, dropout 0.75
#
# Validity:  0.367
# running with learning_rate 4.41E-04, weight scale 1.37E-04, dropout 0
#
# Validity:  0.291
# running with learning_rate 4.41E-04, weight scale 1.37E-04, dropout 0.75
#
# Validity:  0.329
# running with learning_rate 4.41E-04, weight scale 1.09E-04, dropout 0
#
# Validity:  0.313
# running with learning_rate 4.41E-04, weight scale 1.09E-04, dropout 0.75
#
# Validity:  0.334
# running with learning_rate 4.41E-04, weight scale 7.69E-03, dropout 0
#
# Validity:  0.428
# running with learning_rate 4.41E-04, weight scale 7.69E-03, dropout 0.75
#
# Validity:  0.378
# running with learning_rate 4.41E-04, weight scale 5.08E-04, dropout 0
#
# Validity:  0.348
# running with learning_rate 4.41E-04, weight scale 5.08E-04, dropout 0.75
#
# Validity:  0.308
# running with learning_rate 4.41E-04, weight scale 2.77E-04, dropout 0
#
# Validity:  0.306
# running with learning_rate 4.41E-04, weight scale 2.77E-04, dropout 0.75
#
# Validity:  0.319
# running with learning_rate 4.41E-04, weight scale 2.35E-04, dropout 0
#
# Validity:  0.307
# running with learning_rate 4.41E-04, weight scale 2.35E-04, dropout 0.75
#
# Validity:  0.306
# running with learning_rate 4.41E-04, weight scale 5.71E-03, dropout 0
#
# Validity:  0.406
# running with learning_rate 4.41E-04, weight scale 5.71E-03, dropout 0.75
#
# Validity:  0.364
# running with learning_rate 4.41E-04, weight scale 5.06E-02, dropout 0
#
# Validity:  0.397
# running with learning_rate 4.41E-04, weight scale 5.06E-02, dropout 0.75
#
# Validity:  0.326
# running with learning_rate 3.38E-04, weight scale 2.74E-02, dropout 0
#
# Validity:  0.411
# running with learning_rate 3.38E-04, weight scale 2.74E-02, dropout 0.75
#
# Validity:  0.329
# running with learning_rate 3.38E-04, weight scale 2.87E-02, dropout 0
#
# Validity:  0.422
# running with learning_rate 3.38E-04, weight scale 2.87E-02, dropout 0.75
#
# Validity:  0.346
# running with learning_rate 3.38E-04, weight scale 1.37E-04, dropout 0
#
# Validity:  0.281
# running with learning_rate 3.38E-04, weight scale 1.37E-04, dropout 0.75
#
# Validity:  0.318
# running with learning_rate 3.38E-04, weight scale 1.09E-04, dropout 0
#
# Validity:  0.299
# running with learning_rate 3.38E-04, weight scale 1.09E-04, dropout 0.75
#
# Validity:  0.3
# running with learning_rate 3.38E-04, weight scale 7.69E-03, dropout 0
#
# Validity:  0.395
# running with learning_rate 3.38E-04, weight scale 7.69E-03, dropout 0.75
#
# Validity:  0.378
# running with learning_rate 3.38E-04, weight scale 5.08E-04, dropout 0
#
# Validity:  0.355
# running with learning_rate 3.38E-04, weight scale 5.08E-04, dropout 0.75
#
# Validity:  0.282
# running with learning_rate 3.38E-04, weight scale 2.77E-04, dropout 0
#
# Validity:  0.319
# running with learning_rate 3.38E-04, weight scale 2.77E-04, dropout 0.75
#
# Validity:  0.303
# running with learning_rate 3.38E-04, weight scale 2.35E-04, dropout 0
#
# Validity:  0.305
# running with learning_rate 3.38E-04, weight scale 2.35E-04, dropout 0.75
#
# Validity:  0.277
# running with learning_rate 3.38E-04, weight scale 5.71E-03, dropout 0
#
# Validity:  0.394
# running with learning_rate 3.38E-04, weight scale 5.71E-03, dropout 0.75
#
# Validity:  0.324
# running with learning_rate 3.38E-04, weight scale 5.06E-02, dropout 0
#
# Validity:  0.412
# running with learning_rate 3.38E-04, weight scale 5.06E-02, dropout 0.75
#
# Validity:  0.298
# running with learning_rate 1.26E-03, weight scale 2.74E-02, dropout 0
#
# Validity:  0.411
# running with learning_rate 1.26E-03, weight scale 2.74E-02, dropout 0.75
#
# Validity:  0.377
# running with learning_rate 1.26E-03, weight scale 2.87E-02, dropout 0
#
# Validity:  0.419
# running with learning_rate 1.26E-03, weight scale 2.87E-02, dropout 0.75
#
# Validity:  0.382
# running with learning_rate 1.26E-03, weight scale 1.37E-04, dropout 0
#
# Validity:  0.371
# running with learning_rate 1.26E-03, weight scale 1.37E-04, dropout 0.75
#
# Validity:  0.387
# running with learning_rate 1.26E-03, weight scale 1.09E-04, dropout 0
#
# Validity:  0.338
# running with learning_rate 1.26E-03, weight scale 1.09E-04, dropout 0.75
#
# Validity:  0.36
# running with learning_rate 1.26E-03, weight scale 7.69E-03, dropout 0
#
# Validity:  0.387
# running with learning_rate 1.26E-03, weight scale 7.69E-03, dropout 0.75
#
# Validity:  0.379
# running with learning_rate 1.26E-03, weight scale 5.08E-04, dropout 0
#
# Validity:  0.395
# running with learning_rate 1.26E-03, weight scale 5.08E-04, dropout 0.75
#
# Validity:  0.361
# running with learning_rate 1.26E-03, weight scale 2.77E-04, dropout 0
#
# Validity:  0.374
# running with learning_rate 1.26E-03, weight scale 2.77E-04, dropout 0.75
#
# Validity:  0.367
# running with learning_rate 1.26E-03, weight scale 2.35E-04, dropout 0
#
# Validity:  0.391
# running with learning_rate 1.26E-03, weight scale 2.35E-04, dropout 0.75
#
# Validity:  0.329
# running with learning_rate 1.26E-03, weight scale 5.71E-03, dropout 0
#
# Validity:  0.384
# running with learning_rate 1.26E-03, weight scale 5.71E-03, dropout 0.75
#
# Validity:  0.37
# running with learning_rate 1.26E-03, weight scale 5.06E-02, dropout 0
#
# Validity:  0.396
# running with learning_rate 1.26E-03, weight scale 5.06E-02, dropout 0.75
#
# Validity:  0.36
# running with learning_rate 4.35E-04, weight scale 2.74E-02, dropout 0
#
# Validity:  0.421
# running with learning_rate 4.35E-04, weight scale 2.74E-02, dropout 0.75
#
# Validity:  0.353
# running with learning_rate 4.35E-04, weight scale 2.87E-02, dropout 0
#
# Validity:  0.429
# running with learning_rate 4.35E-04, weight scale 2.87E-02, dropout 0.75
#
# Validity:  0.364
# running with learning_rate 4.35E-04, weight scale 1.37E-04, dropout 0
#
# Validity:  0.312
# running with learning_rate 4.35E-04, weight scale 1.37E-04, dropout 0.75
#
# Validity:  0.289
# running with learning_rate 4.35E-04, weight scale 1.09E-04, dropout 0
#
# Validity:  0.294
# running with learning_rate 4.35E-04, weight scale 1.09E-04, dropout 0.75
#
# Validity:  0.302
# running with learning_rate 4.35E-04, weight scale 7.69E-03, dropout 0
#
# Validity:  0.395
# running with learning_rate 4.35E-04, weight scale 7.69E-03, dropout 0.75
#
# Validity:  0.354
# running with learning_rate 4.35E-04, weight scale 5.08E-04, dropout 0
#
# Validity:  0.349
# running with learning_rate 4.35E-04, weight scale 5.08E-04, dropout 0.75
#
# Validity:  0.292
# running with learning_rate 4.35E-04, weight scale 2.77E-04, dropout 0
#
# Validity:  0.357
# running with learning_rate 4.35E-04, weight scale 2.77E-04, dropout 0.75
#
# Validity:  0.33
# running with learning_rate 4.35E-04, weight scale 2.35E-04, dropout 0
#
# Validity:  0.348
# running with learning_rate 4.35E-04, weight scale 2.35E-04, dropout 0.75
#
# Validity:  0.328
# running with learning_rate 4.35E-04, weight scale 5.71E-03, dropout 0
#
# Validity:  0.397
# running with learning_rate 4.35E-04, weight scale 5.71E-03, dropout 0.75
#
# Validity:  0.339
# running with learning_rate 4.35E-04, weight scale 5.06E-02, dropout 0
#
# Validity:  0.397
# running with learning_rate 4.35E-04, weight scale 5.06E-02, dropout 0.75
#
# Validity:  0.335
# running with learning_rate 1.02E-04, weight scale 2.74E-02, dropout 0
#
# Validity:  0.392
# running with learning_rate 1.02E-04, weight scale 2.74E-02, dropout 0.75
#
# Validity:  0.242
# running with learning_rate 1.02E-04, weight scale 2.87E-02, dropout 0
#
# Validity:  0.393
# running with learning_rate 1.02E-04, weight scale 2.87E-02, dropout 0.75
#
# Validity:  0.257
# running with learning_rate 1.02E-04, weight scale 1.37E-04, dropout 0
#
# Validity:  0.238
# running with learning_rate 1.02E-04, weight scale 1.37E-04, dropout 0.75
#
# Validity:  0.258
# running with learning_rate 1.02E-04, weight scale 1.09E-04, dropout 0
#
# Validity:  0.283
# running with learning_rate 1.02E-04, weight scale 1.09E-04, dropout 0.75
#
# Validity:  0.264
# running with learning_rate 1.02E-04, weight scale 7.69E-03, dropout 0
#
# Validity:  0.398
# running with learning_rate 1.02E-04, weight scale 7.69E-03, dropout 0.75
#
# Validity:  0.316
# running with learning_rate 1.02E-04, weight scale 5.08E-04, dropout 0
#
# Validity:  0.275
# running with learning_rate 1.02E-04, weight scale 5.08E-04, dropout 0.75
#
# Validity:  0.251
# running with learning_rate 1.02E-04, weight scale 2.77E-04, dropout 0
#
# Validity:  0.28
# running with learning_rate 1.02E-04, weight scale 2.77E-04, dropout 0.75
#
# Validity:  0.256
# running with learning_rate 1.02E-04, weight scale 2.35E-04, dropout 0
#
# Validity:  0.286
# running with learning_rate 1.02E-04, weight scale 2.35E-04, dropout 0.75
#
# Validity:  0.27
# running with learning_rate 1.02E-04, weight scale 5.71E-03, dropout 0
#
# Validity:  0.384
# running with learning_rate 1.02E-04, weight scale 5.71E-03, dropout 0.75
#
# Validity:  0.286
# running with learning_rate 1.02E-04, weight scale 5.06E-02, dropout 0
#
# Validity:  0.348
# running with learning_rate 1.02E-04, weight scale 5.06E-02, dropout 0.75
#
# Validity:  0.219
# running with learning_rate 8.52E-04, weight scale 2.74E-02, dropout 0
#
# Validity:  0.431
# running with learning_rate 8.52E-04, weight scale 2.74E-02, dropout 0.75
#
# Validity:  0.389
# running with learning_rate 8.52E-04, weight scale 2.87E-02, dropout 0
#
# Validity:  0.422
# running with learning_rate 8.52E-04, weight scale 2.87E-02, dropout 0.75
#
# Validity:  0.391
# running with learning_rate 8.52E-04, weight scale 1.37E-04, dropout 0
#
# Validity:  0.359
# running with learning_rate 8.52E-04, weight scale 1.37E-04, dropout 0.75
#
# Validity:  0.358
# running with learning_rate 8.52E-04, weight scale 1.09E-04, dropout 0
#
# Validity:  0.34
# running with learning_rate 8.52E-04, weight scale 1.09E-04, dropout 0.75
#
# Validity:  0.373
# running with learning_rate 8.52E-04, weight scale 7.69E-03, dropout 0
#
# Validity:  0.402
# running with learning_rate 8.52E-04, weight scale 7.69E-03, dropout 0.75
#
# Validity:  0.371
# running with learning_rate 8.52E-04, weight scale 5.08E-04, dropout 0
#
# Validity:  0.365
# running with learning_rate 8.52E-04, weight scale 5.08E-04, dropout 0.75
#
# Validity:  0.34
# running with learning_rate 8.52E-04, weight scale 2.77E-04, dropout 0
#
# Validity:  0.383
# running with learning_rate 8.52E-04, weight scale 2.77E-04, dropout 0.75
#
# Validity:  0.336
# running with learning_rate 8.52E-04, weight scale 2.35E-04, dropout 0
#
# Validity:  0.366
# running with learning_rate 8.52E-04, weight scale 2.35E-04, dropout 0.75
#
# Validity:  0.364
# running with learning_rate 8.52E-04, weight scale 5.71E-03, dropout 0
#
# Validity:  0.396
# running with learning_rate 8.52E-04, weight scale 5.71E-03, dropout 0.75
#
# Validity:  0.361
# running with learning_rate 8.52E-04, weight scale 5.06E-02, dropout 0
#
# Validity:  0.397
# running with learning_rate 8.52E-04, weight scale 5.06E-02, dropout 0.75
#
# Validity:  0.366
# running with learning_rate 7.16E-02, weight scale 2.74E-02, dropout 0
#
# Validity:  0.37
# running with learning_rate 7.16E-02, weight scale 2.74E-02, dropout 0.75
#
# Validity:  0.249
# running with learning_rate 7.16E-02, weight scale 2.87E-02, dropout 0
#
# Validity:  0.343
# running with learning_rate 7.16E-02, weight scale 2.87E-02, dropout 0.75
#
# Validity:  0.245
# running with learning_rate 7.16E-02, weight scale 1.37E-04, dropout 0
#
# Validity:  0.285
# running with learning_rate 7.16E-02, weight scale 1.37E-04, dropout 0.75
#
# Validity:  0.233
# running with learning_rate 7.16E-02, weight scale 1.09E-04, dropout 0
#
# Validity:  0.348
# running with learning_rate 7.16E-02, weight scale 1.09E-04, dropout 0.75
#
# Validity:  0.239
# running with learning_rate 7.16E-02, weight scale 7.69E-03, dropout 0
#
# Validity:  0.324
# running with learning_rate 7.16E-02, weight scale 7.69E-03, dropout 0.75
#
# Validity:  0.253
# running with learning_rate 7.16E-02, weight scale 5.08E-04, dropout 0
#
# Validity:  0.32
# running with learning_rate 7.16E-02, weight scale 5.08E-04, dropout 0.75
#
# Validity:  0.207
# running with learning_rate 7.16E-02, weight scale 2.77E-04, dropout 0
#
# Validity:  0.337
# running with learning_rate 7.16E-02, weight scale 2.77E-04, dropout 0.75
#
# Validity:  0.263
# running with learning_rate 7.16E-02, weight scale 2.35E-04, dropout 0
#
# Validity:  0.331
# running with learning_rate 7.16E-02, weight scale 2.35E-04, dropout 0.75
#
# Validity:  0.279
# running with learning_rate 7.16E-02, weight scale 5.71E-03, dropout 0
#
# Validity:  0.326
# running with learning_rate 7.16E-02, weight scale 5.71E-03, dropout 0.75
#
# Validity:  0.26
# running with learning_rate 7.16E-02, weight scale 5.06E-02, dropout 0
#
# Validity:  0.35
# running with learning_rate 7.16E-02, weight scale 5.06E-02, dropout 0.75
#
# Validity:  0.241

# %% [markdown]
# # Test you model
# Run your best model on the validation and test sets. You should achieve above 50% accuracy on the validation set.

# %%
X_test=data['X_test']
y_test=data['y_test']
X_val=data['X_val']
y_val=data['y_val']

y_test_pred = np.argmax(best_model.loss(X_test), axis=1)
y_val_pred = np.argmax(best_model.loss(X_val), axis=1)
print 'Validation set accuracy: ', (y_val_pred == y_val).mean()
print 'Test set accuracy: ', (y_test_pred == y_test).mean()

print 'Hyper-parameters for the best model:', best_parameter
# Out:
# Validation set accuracy:  0.405
# Test set accuracy:  0.385
# Hyper-parameters for the best model: {'learning_rate': 0.00085158226849693023, 'dropout': 0, 'weight': 0.027410695297063883, 'val': 0.43099999999999999}

# %%
learning_rate=best_parameter['learning_rate']
dropout=best_parameter['dropout']
weight=best_parameter['weight']
    
model = FullyConnectedNet([100, 100, 100, 100, 100], 
                          weight_scale=weight,dropout=dropout,use_batchnorm=True)

solver = Solver(model, data,
          num_epochs=8, batch_size=100,
          update_rule='adam',
          optim_config={
            'learning_rate': learning_rate
          },
          verbose=True, print_every=200)
solvers[name] = solver
solver.train()
print
# Out:
# (Iteration 1 / 3920) loss: 2.293616
# (Epoch 0 / 8) train acc: 0.129000; val_acc: 0.137000
# (Iteration 201 / 3920) loss: 1.615009
# (Iteration 401 / 3920) loss: 1.707883
# (Epoch 1 / 8) train acc: 0.490000; val_acc: 0.476000
# (Iteration 601 / 3920) loss: 1.762117
# (Iteration 801 / 3920) loss: 1.260313
# (Epoch 2 / 8) train acc: 0.532000; val_acc: 0.517000
# (Iteration 1001 / 3920) loss: 1.225624
# (Iteration 1201 / 3920) loss: 1.213862
# (Iteration 1401 / 3920) loss: 1.290617
# (Epoch 3 / 8) train acc: 0.562000; val_acc: 0.526000
# (Iteration 1601 / 3920) loss: 1.198297
# (Iteration 1801 / 3920) loss: 1.469787
# (Epoch 4 / 8) train acc: 0.584000; val_acc: 0.538000
# (Iteration 2001 / 3920) loss: 1.283273
# (Iteration 2201 / 3920) loss: 1.036888
# (Iteration 2401 / 3920) loss: 1.237534
# (Epoch 5 / 8) train acc: 0.608000; val_acc: 0.541000
# (Iteration 2601 / 3920) loss: 1.250619
# (Iteration 2801 / 3920) loss: 1.254952
# (Epoch 6 / 8) train acc: 0.627000; val_acc: 0.534000
# (Iteration 3001 / 3920) loss: 1.130135
# (Iteration 3201 / 3920) loss: 1.112671
# (Iteration 3401 / 3920) loss: 1.032222
# (Epoch 7 / 8) train acc: 0.607000; val_acc: 0.540000
# (Iteration 3601 / 3920) loss: 1.066803
# (Iteration 3801 / 3920) loss: 1.089972
# (Epoch 8 / 8) train acc: 0.662000; val_acc: 0.543000

# %%
y_test_pred = np.argmax(model.loss(X_test), axis=1)
y_val_pred = np.argmax(model.loss(X_val), axis=1)
print 'Validation set accuracy: ', (y_val_pred == y_val).mean()
print 'Test set accuracy: ', (y_test_pred == y_test).mean()

plt.figure(figsize=[1,1])
plt.subplot(2, 1, 1)
plt.title('Training loss')
plt.plot(solver.loss_history, 'o')
plt.xlabel('Iteration')

plt.subplot(2, 1, 2)
plt.title('Accuracy')
plt.plot(solver.train_acc_history, '-o', label='train')
plt.plot(solver.val_acc_history, '-o', label='val')
plt.plot([0.5] * len(solver.val_acc_history), 'k--')
plt.xlabel('Epoch')
plt.legend(loc='lower right')
plt.gcf().set_size_inches(15, 12)
plt.show()
# Out:
# Validation set accuracy:  0.543
# Test set accuracy:  0.543
